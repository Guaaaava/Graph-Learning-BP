# %%
import torch
import numpy as np

# 导入各个模块
from GNN_learning.train import train_gnn_sparsifier
from NBP_ST.BFS_tree import extract_bfs_tree_edges
from GNN_learning.bp import gaussian_bp_localization
from GNN_learning.visualize_topology import plot_topology_comparison

TORCH_SEED = 6          # 随机种子
LAMBDA_REG = 0.3       # 超参数 lambda
EPOCHS = 1000

def calculate_metrics(estimated_pos, true_pos, estimated_sigma):
    """评价指标：RMSE 和 误差校准度"""
    # 1. 真实绝对误差 (MSE 和 RMSE)
    errors = estimated_pos - true_pos
    mse_per_node = torch.sum(errors**2, dim=1) # 每个节点的欧式距离平方
    mean_mse = torch.mean(mse_per_node).item()
    rmse = np.sqrt(mean_mse)
    
    # 2. 算法自我评估的误差 (协方差矩阵的迹 Trace)
    # 迹越小，代表算法觉得自己越“准”
    trace_per_node = torch.diagonal(estimated_sigma, dim1=-2, dim2=-1).sum(dim=-1)
    mean_trace = torch.mean(trace_per_node).item()
    
    # 3. 过度自信倍率 (Overconfidence Ratio)
    # 理想状态下，实际误差 MSE 应该等于算法估计的 Trace (比值为 1.0)
    # 如果比值 >> 1.0，说明算法过度自信
    overconfidence_ratio = mean_mse / mean_trace
    
    return rmse, mean_trace, overconfidence_ratio

if __name__ == "__main__":
    torch.manual_seed(TORCH_SEED)
    
    # ==========================================
    # 1. 数据准备与图拓扑生成
    # ==========================================
    print(">>> [1/4] 正在生成物理场景与 GNN 拓扑...")
    model, gnn_weights, data, final_edges, crlb_final, crlb_baseline = train_gnn_sparsifier(
        epochs=EPOCHS, lr=0.01, lambda_reg=LAMBDA_REG
    )
    
    agents_pos_true = data['true_agents_pos']
    agents_pos_init = data['init_agents_pos']
    anchors_pos = data['anchors_pos']
    edge_index = data['edge_index']
    measurements = data['measurements']
    edge_variances = data['edge_variances']
    is_anchor_edge = data['is_anchor_edge']
    E_total = edge_index.shape[1]
    
    print(f"\n>>> [2/4] 正在提取 BFS 树...")
    bfs_weights = extract_bfs_tree_edges(agents_pos_true.shape[0], anchors_pos.shape[0], edge_index)
    
    dense_weights = torch.ones(E_total)
    
    # ==========================================
    # 2. 将三种拓扑输入高斯 BP 算法进行 25 轮迭代
    # ==========================================
    print("\n>>> [3/4] 正在运行 Gaussian BP 定位算法...")
    num_iters = 25
    
    # 测试 A：原图 (Dense)
    mu_dense, sigma_dense, iters_dense = gaussian_bp_localization(
        agents_pos_init, anchors_pos, edge_index, measurements, edge_variances, 
        is_anchor_edge, edge_weights=dense_weights, num_iters=num_iters
    )
    
    # 测试 B：BFS 树 (Tree)
    mu_bfs, sigma_bfs, iters_bfs = gaussian_bp_localization(
        agents_pos_init, anchors_pos, edge_index, measurements, edge_variances, 
        is_anchor_edge, edge_weights=bfs_weights, num_iters=num_iters
    )
    
    # 测试 C：GNN 稀疏图 (Sparse)
    mu_gnn, sigma_gnn, iters_gnn = gaussian_bp_localization(
        agents_pos_init, anchors_pos, edge_index, measurements, edge_variances, 
        is_anchor_edge, edge_weights=gnn_weights, num_iters=num_iters
    )
    
    # ==========================================
    # 3. 结果核算与打印
    # ==========================================
    print("\n>>> [4/4] 结果核算中...")
    print("=" * 90)
    print(f"{'测试模型':<10} | {'保留边数':<8} | {'收敛迭代':<4} | {'定位 RMSE':<8} | {'过度自信倍率':<15}")
    print("-" * 90)
    
    # Dense
    rmse_dense, trace_dense, oc_dense = calculate_metrics(mu_dense, agents_pos_true, sigma_dense)
    print(f"{'1. 原图 (Dense)':<14} | {E_total:<8} | {iters_dense:<8} | {rmse_dense:<10.4f} | {oc_dense:<15.2f}")
    
    # BFS
    rmse_bfs, trace_bfs, oc_bfs = calculate_metrics(mu_bfs, agents_pos_true, sigma_bfs)
    edges_bfs = int(torch.sum(bfs_weights).item())
    print(f"{'2. 传统树 (BFS)':<13} | {edges_bfs:<8} | {iters_bfs:<8} | {rmse_bfs:<10.4f} | {oc_bfs:<15.2f}")
    
    # GNN
    rmse_gnn, trace_gnn, oc_gnn = calculate_metrics(mu_gnn, agents_pos_true, sigma_gnn)
    edges_gnn = int(torch.sum(gnn_weights).item())
    print(f"{'3. 智能图 (GNN)':<13} | {edges_gnn:<8} | {iters_gnn:<8} | {rmse_gnn:<10.4f} | {oc_gnn:<15.2f}")
    print("=" * 90)

    plot_topology_comparison(data, gnn_weights, bfs_weights) # 拓扑对比图
# Out:
# >>> [1/4] 正在生成物理场景与 GNN 拓扑...
# >>> [1/3] 初始化协同定位物理场景...
# >>> [2/3] 计算稠密全图基准 CRLB...
#     原始稠密图边数: 101
#     原始稠密图 CRLB: 63.5749
#
# >>> [3/3] 开始 GNN 剪枝训练...
# Epoch 000 | Total Loss: 12.2539 | CRLB: 269997.5625 (是基准的 4246.92 倍) | 保留边数: 13/101 | Tau: 0.997
# Epoch 020 | Total Loss: 23.2265 | CRLB: 97.3940 (是基准的 1.53 倍) | 保留边数: 76/101 | Tau: 0.941
# Epoch 040 | Total Loss: 26.6701 | CRLB: 10120.1504 (是基准的 159.18 倍) | 保留边数: 72/101 | Tau: 0.889
# Epoch 060 | Total Loss: 18.6712 | CRLB: 167.9102 (是基准的 2.64 倍) | 保留边数: 59/101 | Tau: 0.839
# Epoch 080 | Total Loss: 20.4921 | CRLB: 421.7274 (是基准的 6.63 倍) | 保留边数: 62/101 | Tau: 0.792
# Epoch 100 | Total Loss: 18.8582 | CRLB: 497.9317 (是基准的 7.83 倍) | 保留边数: 56/101 | Tau: 0.748
# Epoch 120 | Total Loss: 24.0987 | CRLB: 11509.1260 (是基准的 181.03 倍) | 保留边数: 63/101 | Tau: 0.706
# Epoch 140 | Total Loss: 20.4300 | CRLB: 10745.2227 (是基准的 169.02 倍) | 保留边数: 51/101 | Tau: 0.666
# Epoch 160 | Total Loss: 20.0885 | CRLB: 3104.7998 (是基准的 48.84 倍) | 保留边数: 54/101 | Tau: 0.629
# Epoch 180 | Total Loss: 18.8093 | CRLB: 192.7818 (是基准的 3.03 倍) | 保留边数: 59/101 | Tau: 0.594
# Epoch 200 | Total Loss: 22.1878 | CRLB: 10301.4736 (是基准的 162.04 倍) | 保留边数: 57/101 | Tau: 0.561
# Epoch 220 | Total Loss: 22.2831 | CRLB: 8394.5039 (是基准的 132.04 倍) | 保留边数: 58/101 | Tau: 0.529
# Epoch 240 | Total Loss: 19.8701 | CRLB: 305.5996 (是基准的 4.81 倍) | 保留边数: 61/101 | Tau: 0.500
# Epoch 260 | Total Loss: 19.8375 | CRLB: 399.3040 (是基准的 6.28 倍) | 保留边数: 60/101 | Tau: 0.472
# Epoch 280 | Total Loss: 21.2813 | CRLB: 153.4746 (是基准的 2.41 倍) | 保留边数: 68/101 | Tau: 0.445
# Epoch 300 | Total Loss: 23.0797 | CRLB: 10217.7412 (是基准的 160.72 倍) | 保留边数: 60/101 | Tau: 0.420
# Epoch 320 | Total Loss: 21.7540 | CRLB: 2714.1348 (是基准的 42.69 倍) | 保留边数: 60/101 | Tau: 0.397
# Epoch 340 | Total Loss: 19.2991 | CRLB: 573.2208 (是基准的 9.02 倍) | 保留边数: 57/101 | Tau: 0.375
# Epoch 360 | Total Loss: 19.8934 | CRLB: 231.7369 (是基准的 3.65 倍) | 保留边数: 62/101 | Tau: 0.354
# Epoch 380 | Total Loss: 18.5133 | CRLB: 261.2574 (是基准的 4.11 倍) | 保留边数: 57/101 | Tau: 0.334
# Epoch 400 | Total Loss: 22.4808 | CRLB: 10229.6846 (是基准的 160.91 倍) | 保留边数: 58/101 | Tau: 0.315
# Epoch 420 | Total Loss: 22.7837 | CRLB: 10259.4189 (是基准的 161.38 倍) | 保留边数: 59/101 | Tau: 0.298
# Epoch 440 | Total Loss: 20.2417 | CRLB: 328.2903 (是基准的 5.16 倍) | 保留边数: 62/101 | Tau: 0.281
# Epoch 460 | Total Loss: 22.7775 | CRLB: 10196.1240 (是基准的 160.38 倍) | 保留边数: 59/101 | Tau: 0.265
# Epoch 480 | Total Loss: 19.1847 | CRLB: 153.9872 (是基准的 2.42 倍) | 保留边数: 61/101 | Tau: 0.250
# Epoch 500 | Total Loss: 21.0306 | CRLB: 217.6237 (是基准的 3.42 倍) | 保留边数: 66/101 | Tau: 0.236
# Epoch 520 | Total Loss: 19.5054 | CRLB: 386.7027 (是基准的 6.08 倍) | 保留边数: 59/101 | Tau: 0.223
# Epoch 540 | Total Loss: 22.1773 | CRLB: 10193.2656 (是基准的 160.33 倍) | 保留边数: 57/101 | Tau: 0.211
# Epoch 560 | Total Loss: 17.3493 | CRLB: 365.6038 (是基准的 5.75 倍) | 保留边数: 52/101 | Tau: 0.199
# Epoch 580 | Total Loss: 19.1304 | CRLB: 196.8782 (是基准的 3.10 倍) | 保留边数: 60/101 | Tau: 0.188
# Epoch 600 | Total Loss: 18.2061 | CRLB: 350.1367 (是基准的 5.51 倍) | 保留边数: 55/101 | Tau: 0.177
# Epoch 620 | Total Loss: 19.1062 | CRLB: 142.3744 (是基准的 2.24 倍) | 保留边数: 61/101 | Tau: 0.167
# Epoch 640 | Total Loss: 19.6168 | CRLB: 237.2191 (是基准的 3.73 倍) | 保留边数: 61/101 | Tau: 0.158
# Epoch 660 | Total Loss: 19.0981 | CRLB: 632.8981 (是基准的 9.96 倍) | 保留边数: 56/101 | Tau: 0.149
# Epoch 680 | Total Loss: 19.8688 | CRLB: 167.4988 (是基准的 2.63 倍) | 保留边数: 63/101 | Tau: 0.141
# Epoch 700 | Total Loss: 20.6116 | CRLB: 641.4880 (是基准的 10.09 倍) | 保留边数: 61/101 | Tau: 0.133
# Epoch 720 | Total Loss: 20.6969 | CRLB: 10394.9209 (是基准的 163.51 倍) | 保留边数: 52/101 | Tau: 0.126
# Epoch 740 | Total Loss: 19.2319 | CRLB: 161.4339 (是基准的 2.54 倍) | 保留边数: 61/101 | Tau: 0.119
# Epoch 760 | Total Loss: 19.5317 | CRLB: 294.1057 (是基准的 4.63 倍) | 保留边数: 60/101 | Tau: 0.112
# Epoch 780 | Total Loss: 19.1414 | CRLB: 489.6054 (是基准的 7.70 倍) | 保留边数: 57/101 | Tau: 0.106
# Epoch 800 | Total Loss: 21.2817 | CRLB: 10238.6670 (是基准的 161.05 倍) | 保留边数: 54/101 | Tau: 0.100
# Epoch 820 | Total Loss: 19.0391 | CRLB: 242.5767 (是基准的 3.82 倍) | 保留边数: 59/101 | Tau: 0.100
# Epoch 840 | Total Loss: 19.0303 | CRLB: 178.1349 (是基准的 2.80 倍) | 保留边数: 60/101 | Tau: 0.100
# Epoch 860 | Total Loss: 20.7007 | CRLB: 10434.8721 (是基准的 164.13 倍) | 保留边数: 52/101 | Tau: 0.100
# Epoch 880 | Total Loss: 17.8685 | CRLB: 249.8144 (是基准的 3.93 倍) | 保留边数: 55/101 | Tau: 0.100
# Epoch 900 | Total Loss: 18.1126 | CRLB: 175.0060 (是基准的 2.75 倍) | 保留边数: 57/101 | Tau: 0.100
# Epoch 920 | Total Loss: 18.8581 | CRLB: 149.9501 (是基准的 2.36 倍) | 保留边数: 60/101 | Tau: 0.100
# Epoch 940 | Total Loss: 22.0628 | CRLB: 6734.7339 (是基准的 105.93 倍) | 保留边数: 58/101 | Tau: 0.100
# Epoch 960 | Total Loss: 19.7633 | CRLB: 500.4638 (是基准的 7.87 倍) | 保留边数: 59/101 | Tau: 0.100
# Epoch 980 | Total Loss: 19.6347 | CRLB: 241.5032 (是基准的 3.80 倍) | 保留边数: 61/101 | Tau: 0.100
# Epoch 999 | Total Loss: 22.6083 | CRLB: 2592.9426 (是基准的 40.79 倍) | 保留边数: 63/101 | Tau: 0.100
#
# >>> 训练完成！
# 最终成果：网络从 101 条边精简至 71 条边！
# 最终干净图 CRLB: 113.4272 (是基准的 1.78 倍)
#
# >>> [2/4] 正在提取 BFS 树...
#
# >>> [3/4] 正在运行 Gaussian BP 定位算法...
#
# >>> [4/4] 结果核算中...
# ==========================================================================================
# 测试模型       | 保留边数     | 收敛迭代 | 定位 RMSE  | 过度自信倍率
# ------------------------------------------------------------------------------------------
# 1. 原图 (Dense)  | 101      | 25       | 2.0586     | 1.85
# 2. 传统树 (BFS)  | 27       | 25       | 41.0452    | 0.29
# 3. 智能图 (GNN)  | 71       | 25       | 2.2913     | 1.01
# ==========================================================================================
