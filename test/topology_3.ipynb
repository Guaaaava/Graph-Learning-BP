# %%
import torch
import numpy as np

# 导入各个模块
from GNN_learning.train import train_gnn_sparsifier
from NBP_ST.BFS_tree import extract_bfs_tree_edges
from GNN_learning.bp import gaussian_bp_localization
from GNN_learning.visualize_topology import plot_topology_comparison

TORCH_SEED = 3          # 随机种子
LAMBDA_REG = 0.25       # 超参数 lambda
EPOCHS = 1000

def calculate_metrics(estimated_pos, true_pos, estimated_sigma):
    """评价指标：RMSE 和 误差校准度"""
    # 1. 真实绝对误差 (MSE 和 RMSE)
    errors = estimated_pos - true_pos
    mse_per_node = torch.sum(errors**2, dim=1) # 每个节点的欧式距离平方
    mean_mse = torch.mean(mse_per_node).item()
    rmse = np.sqrt(mean_mse)
    
    # 2. 算法自我评估的误差 (协方差矩阵的迹 Trace)
    # 迹越小，代表算法觉得自己越“准”
    trace_per_node = torch.diagonal(estimated_sigma, dim1=-2, dim2=-1).sum(dim=-1)
    mean_trace = torch.mean(trace_per_node).item()
    
    # 3. 过度自信倍率 (Overconfidence Ratio)
    # 理想状态下，实际误差 MSE 应该等于算法估计的 Trace (比值为 1.0)
    # 如果比值 >> 1.0，说明算法过度自信
    overconfidence_ratio = mean_mse / mean_trace
    
    return rmse, mean_trace, overconfidence_ratio

if __name__ == "__main__":
    torch.manual_seed(TORCH_SEED)
    
    # ==========================================
    # 1. 数据准备与图拓扑生成
    # ==========================================
    print(">>> [1/4] 正在生成物理场景与 GNN 拓扑...")
    model, gnn_weights, data, final_edges, crlb_final, crlb_baseline = train_gnn_sparsifier(
        epochs=EPOCHS, lr=0.01, lambda_reg=LAMBDA_REG
    )
    
    agents_pos_true = data['true_agents_pos']
    agents_pos_init = data['init_agents_pos']
    anchors_pos = data['anchors_pos']
    edge_index = data['edge_index']
    measurements = data['measurements']
    edge_variances = data['edge_variances']
    is_anchor_edge = data['is_anchor_edge']
    E_total = edge_index.shape[1]
    
    print(f"\n>>> [2/4] 正在提取 BFS 树...")
    bfs_weights = extract_bfs_tree_edges(agents_pos_true.shape[0], anchors_pos.shape[0], edge_index)
    
    dense_weights = torch.ones(E_total)
    
    # ==========================================
    # 2. 将三种拓扑输入高斯 BP 算法进行 25 轮迭代
    # ==========================================
    print("\n>>> [3/4] 正在运行 Gaussian BP 定位算法...")
    num_iters = 25
    
    # 测试 A：原图 (Dense)
    mu_dense, sigma_dense, iters_dense = gaussian_bp_localization(
        agents_pos_init, anchors_pos, edge_index, measurements, edge_variances, 
        is_anchor_edge, edge_weights=dense_weights, num_iters=num_iters
    )
    
    # 测试 B：BFS 树 (Tree)
    mu_bfs, sigma_bfs, iters_bfs = gaussian_bp_localization(
        agents_pos_init, anchors_pos, edge_index, measurements, edge_variances, 
        is_anchor_edge, edge_weights=bfs_weights, num_iters=num_iters
    )
    
    # 测试 C：GNN 稀疏图 (Sparse)
    mu_gnn, sigma_gnn, iters_gnn = gaussian_bp_localization(
        agents_pos_init, anchors_pos, edge_index, measurements, edge_variances, 
        is_anchor_edge, edge_weights=gnn_weights, num_iters=num_iters
    )
    
    # ==========================================
    # 3. 结果核算与打印
    # ==========================================
    print("\n>>> [4/4] 结果核算中...")
    print("=" * 90)
    print(f"{'测试模型':<10} | {'保留边数':<8} | {'收敛迭代':<4} | {'定位 RMSE':<8} | {'过度自信倍率':<15}")
    print("-" * 90)
    
    # Dense
    rmse_dense, trace_dense, oc_dense = calculate_metrics(mu_dense, agents_pos_true, sigma_dense)
    print(f"{'1. 原图 (Dense)':<14} | {E_total:<8} | {iters_dense:<8} | {rmse_dense:<10.4f} | {oc_dense:<15.2f}")
    
    # BFS
    rmse_bfs, trace_bfs, oc_bfs = calculate_metrics(mu_bfs, agents_pos_true, sigma_bfs)
    edges_bfs = int(torch.sum(bfs_weights).item())
    print(f"{'2. 传统树 (BFS)':<13} | {edges_bfs:<8} | {iters_bfs:<8} | {rmse_bfs:<10.4f} | {oc_bfs:<15.2f}")
    
    # GNN
    rmse_gnn, trace_gnn, oc_gnn = calculate_metrics(mu_gnn, agents_pos_true, sigma_gnn)
    edges_gnn = int(torch.sum(gnn_weights).item())
    print(f"{'3. 智能图 (GNN)':<13} | {edges_gnn:<8} | {iters_gnn:<8} | {rmse_gnn:<10.4f} | {oc_gnn:<15.2f}")
    print("=" * 90)

    plot_topology_comparison(data, gnn_weights, bfs_weights) # 拓扑对比图
# Out:
# >>> [1/4] 正在生成物理场景与 GNN 拓扑...
# >>> [1/3] 初始化协同定位物理场景...
# >>> [2/3] 计算稠密全图基准 CRLB...
#     原始稠密图边数: 89
#     原始稠密图 CRLB: 10138.3936
#
# >>> [3/3] 开始 GNN 剪枝训练...
# Epoch 000 | Total Loss: 18.7794 | CRLB: 10440.9092 (是基准的 1.03 倍) | 保留边数: 75/89 | Tau: 0.997
# Epoch 020 | Total Loss: 14.2629 | CRLB: 10270.4307 (是基准的 1.01 倍) | 保留边数: 57/89 | Tau: 0.941
# Epoch 040 | Total Loss: 16.7571 | CRLB: 10210.7500 (是基准的 1.01 倍) | 保留边数: 67/89 | Tau: 0.889
# Epoch 060 | Total Loss: 12.5614 | CRLB: 10780.8799 (是基准的 1.06 倍) | 保留边数: 50/89 | Tau: 0.839
# Epoch 080 | Total Loss: 15.0069 | CRLB: 10208.1846 (是基准的 1.01 倍) | 保留边数: 60/89 | Tau: 0.792
# Epoch 100 | Total Loss: 14.6903 | CRLB: 20219.0000 (是基准的 1.99 倍) | 保留边数: 56/89 | Tau: 0.748
# Epoch 120 | Total Loss: 12.7900 | CRLB: 10551.8662 (是基准的 1.04 倍) | 保留边数: 51/89 | Tau: 0.706
# Epoch 140 | Total Loss: 14.9547 | CRLB: 20512.3340 (是基准的 2.02 倍) | 保留边数: 57/89 | Tau: 0.666
# Epoch 160 | Total Loss: 12.1129 | CRLB: 30854.3594 (是基准的 3.04 倍) | 保留边数: 44/89 | Tau: 0.629
# Epoch 180 | Total Loss: 13.7821 | CRLB: 10469.5439 (是基准的 1.03 倍) | 保留边数: 55/89 | Tau: 0.594
# Epoch 200 | Total Loss: 13.8432 | CRLB: 30250.0566 (是基准的 2.98 倍) | 保留边数: 51/89 | Tau: 0.561
# Epoch 220 | Total Loss: 12.0408 | CRLB: 13560.5254 (是基准的 1.34 倍) | 保留边数: 47/89 | Tau: 0.529
# Epoch 240 | Total Loss: 11.7908 | CRLB: 10560.8174 (是基准的 1.04 倍) | 保留边数: 47/89 | Tau: 0.500
# Epoch 260 | Total Loss: 12.2003 | CRLB: 20423.2617 (是基准的 2.01 倍) | 保留边数: 46/89 | Tau: 0.472
# Epoch 280 | Total Loss: 12.5977 | CRLB: 14354.1240 (是基准的 1.42 倍) | 保留边数: 49/89 | Tau: 0.445
# Epoch 300 | Total Loss: 12.5676 | CRLB: 10847.5400 (是基准的 1.07 倍) | 保留边数: 50/89 | Tau: 0.420
# Epoch 320 | Total Loss: 12.0471 | CRLB: 10627.5859 (是基准的 1.05 倍) | 保留边数: 48/89 | Tau: 0.397
# Epoch 340 | Total Loss: 11.3102 | CRLB: 22795.7656 (是基准的 2.25 倍) | 保留边数: 42/89 | Tau: 0.375
# Epoch 360 | Total Loss: 11.5259 | CRLB: 10404.4189 (是基准的 1.03 倍) | 保留边数: 46/89 | Tau: 0.354
# Epoch 380 | Total Loss: 11.7190 | CRLB: 20807.5020 (是基准的 2.05 倍) | 保留边数: 44/89 | Tau: 0.334
# Epoch 400 | Total Loss: 12.2093 | CRLB: 20606.5664 (是基准的 2.03 倍) | 保留边数: 46/89 | Tau: 0.315
# Epoch 420 | Total Loss: 12.0930 | CRLB: 30246.4102 (是基准的 2.98 倍) | 保留边数: 44/89 | Tau: 0.298
# Epoch 440 | Total Loss: 11.5548 | CRLB: 47994.7578 (是基准的 4.73 倍) | 保留边数: 40/89 | Tau: 0.281
# Epoch 460 | Total Loss: 12.6074 | CRLB: 30683.3789 (是基准的 3.03 倍) | 保留边数: 46/89 | Tau: 0.265
# Epoch 480 | Total Loss: 11.7247 | CRLB: 20927.7246 (是基准的 2.06 倍) | 保留边数: 44/89 | Tau: 0.250
# Epoch 500 | Total Loss: 14.0302 | CRLB: 10449.2920 (是基准的 1.03 倍) | 保留边数: 56/89 | Tau: 0.236
# Epoch 520 | Total Loss: 11.3715 | CRLB: 51306.6445 (是基准的 5.06 倍) | 保留边数: 39/89 | Tau: 0.223
# Epoch 540 | Total Loss: 12.5331 | CRLB: 10479.6299 (是基准的 1.03 倍) | 保留边数: 50/89 | Tau: 0.211
# Epoch 560 | Total Loss: 11.2264 | CRLB: 20962.7051 (是基准的 2.07 倍) | 保留边数: 42/89 | Tau: 0.199
# Epoch 580 | Total Loss: 12.1671 | CRLB: 32571.3516 (是基准的 3.21 倍) | 保留边数: 44/89 | Tau: 0.188
# Epoch 600 | Total Loss: 12.6942 | CRLB: 20297.3301 (是基准的 2.00 倍) | 保留边数: 48/89 | Tau: 0.177
# Epoch 620 | Total Loss: 12.7021 | CRLB: 20458.5488 (是基准的 2.02 倍) | 保留边数: 48/89 | Tau: 0.167
# Epoch 640 | Total Loss: 12.2684 | CRLB: 10326.8838 (是基准的 1.02 倍) | 保留边数: 49/89 | Tau: 0.158
# Epoch 660 | Total Loss: 12.7850 | CRLB: 10499.7148 (是基准的 1.04 倍) | 保留边数: 51/89 | Tau: 0.149
# Epoch 680 | Total Loss: 11.7886 | CRLB: 10537.0195 (是基准的 1.04 倍) | 保留边数: 47/89 | Tau: 0.141
# Epoch 700 | Total Loss: 11.5257 | CRLB: 10402.6768 (是基准的 1.03 倍) | 保留边数: 46/89 | Tau: 0.133
# Epoch 720 | Total Loss: 12.5295 | CRLB: 10442.3086 (是基准的 1.03 倍) | 保留边数: 50/89 | Tau: 0.126
# Epoch 740 | Total Loss: 13.5288 | CRLB: 10434.1719 (是基准的 1.03 倍) | 保留边数: 54/89 | Tau: 0.119
# Epoch 760 | Total Loss: 11.3028 | CRLB: 10687.6006 (是基准的 1.05 倍) | 保留边数: 45/89 | Tau: 0.112
# Epoch 780 | Total Loss: 12.0906 | CRLB: 11099.8125 (是基准的 1.09 倍) | 保留边数: 48/89 | Tau: 0.106
# Epoch 800 | Total Loss: 12.1070 | CRLB: 11283.2461 (是基准的 1.11 倍) | 保留边数: 48/89 | Tau: 0.100
# Epoch 820 | Total Loss: 11.1362 | CRLB: 11617.8555 (是基准的 1.15 倍) | 保留边数: 44/89 | Tau: 0.100
# Epoch 840 | Total Loss: 12.3544 | CRLB: 30590.2852 (是基准的 3.02 倍) | 保留边数: 45/89 | Tau: 0.100
# Epoch 860 | Total Loss: 12.1987 | CRLB: 20388.7715 (是基准的 2.01 倍) | 保留边数: 46/89 | Tau: 0.100
# Epoch 880 | Total Loss: 11.7631 | CRLB: 10271.9443 (是基准的 1.01 倍) | 保留边数: 47/89 | Tau: 0.100
# Epoch 900 | Total Loss: 11.0631 | CRLB: 10799.1484 (是基准的 1.07 倍) | 保留边数: 44/89 | Tau: 0.100
# Epoch 920 | Total Loss: 13.0216 | CRLB: 10360.2002 (是基准的 1.02 倍) | 保留边数: 52/89 | Tau: 0.100
# Epoch 940 | Total Loss: 12.5498 | CRLB: 10656.0693 (是基准的 1.05 倍) | 保留边数: 50/89 | Tau: 0.100
# Epoch 960 | Total Loss: 12.0085 | CRLB: 13128.9688 (是基准的 1.29 倍) | 保留边数: 47/89 | Tau: 0.100
# Epoch 980 | Total Loss: 11.4712 | CRLB: 12648.7871 (是基准的 1.25 倍) | 保留边数: 45/89 | Tau: 0.100
# Epoch 999 | Total Loss: 12.2476 | CRLB: 21411.8125 (是基准的 2.11 倍) | 保留边数: 46/89 | Tau: 0.100
#
# >>> 训练完成！
# 最终成果：网络从 89 条边精简至 42 条边！
# 最终干净图 CRLB: 40415.7305 (是基准的 3.99 倍)
#
# >>> [2/4] 正在提取 BFS 树...
#
# >>> [3/4] 正在运行 Gaussian BP 定位算法...
#
# >>> [4/4] 结果核算中...
# ==========================================================================================
# 测试模型       | 保留边数     | 收敛迭代 | 定位 RMSE  | 过度自信倍率
# ------------------------------------------------------------------------------------------
# 1. 原图 (Dense)  | 89       | 25       | 15.4613    | 0.47
# 2. 传统树 (BFS)  | 20       | 25       | 59.3217    | 0.40
# 3. 智能图 (GNN)  | 42       | 25       | 16.9034    | 0.28
# ==========================================================================================
